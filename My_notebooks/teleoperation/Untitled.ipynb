# %%
## ROS Subsriber

# %%
import sys
sys.path.insert(0, '/opt/ros/noetic/lib/python3/dist-packages')

import rospy
rospy.init_node('listener', anonymous=True)

from geometry_msgs.msg import Twist

def callback_0(data):
    rospy.loginfo(rospy.get_caller_id(), data)
    print(data)
    
rospy.Subscriber('cmd_vel', Twist, callback_0)
rospy.spin()
# Out:
# [ERROR] [1612307466.668403]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307466.918993]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307467.175404]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307467.426576]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307467.680297]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307467.937617]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307468.190461]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307468.445734]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307468.694506]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307468.949739]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307469.202957]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307469.457908]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307469.709611]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307469.963427]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307470.219492]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307470.469896]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307470.719306]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307470.976505]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307471.228549]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307471.484733]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307471.737154]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307471.990144]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307472.247146]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307472.495745]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307472.746695]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307472.999483]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307473.252947]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307473.506647]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307473.757952]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307474.011784]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307474.266734]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307474.521735]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
# ...
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307717.536242]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307717.790096]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307718.041281]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307718.295418]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307718.548954]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307718.799542]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307719.054615]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307719.310873]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307719.565598]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#
# [ERROR] [1612307719.818199]: bad callback: <function callback_0 at 0x7f8f4a36a8>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-6d3679025db5>", line 10, in callback_0
#     rospy.loginfo(rospy.get_caller_id(), data)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 190, in loginfo
#     _base_logger(msg, args, kwargs, level='info')
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/core.py", line 183, in _base_logger
#     logfunc(msg, *args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1308, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1444, in _log
#     self.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1454, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 1516, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 865, in handle
#     self.emit(record)
#   File "/opt/ros/noetic/lib/python3/dist-packages/rosgraph/roslogging.py", line 246, in emit
#     record_message = _defaultFormatter.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
